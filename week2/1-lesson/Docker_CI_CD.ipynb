# %% [markdown]
# <img style="width: 100%;" src="data:image/gif;base64,..."/>

# %% [markdown]
# <div style="font-size: 1.2em; background-color: #b5add6; padding: 1em; font-weight: bold; color: ;">
# Une petite histoire
# <br>
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img style="width: 14em;" src="data:image/gif;base64,..." alt="carapuce"/>
#     <div style="text-align: left;">
#         <a href="https://shinyhunters.com/images/shiny/8.gif" style="text-decoration: underline; color: #b5add6;">image source</a>
#     </div>
# </div>

# %% [markdown]
# <div style="font-size: 1.15em; background-color: #f8f8f8; padding: 1.2em;">
#     <b>Carabaffe</b> est une évolution de Carapuce. Tout comme Carapuce, il est de type Eau. Avec sa carapace plus grande et ses compétences améliorées, il est prêt à relever de nouveaux défis. <br><br>
#     Maintenant que nous avons maîtrisé les compétences de la première semaine en devenant des Carapuces, passons à l'étape suivante. En tant que Carabaffe, nous explorerons des concepts plus avancés dans le déploiement de modèles de ML. <br><br>
#     <b>Objectifs:</b>
#     <ul>
#         <li>Déployer dans des conteneurs Docker</li>
#         <li>Mise en place de CI/CD pour déployer ces conteneurs</li>
#     </ul>
#     C'est le moment de passer à l'étape suivante et de devenir des experts en déploiement de modèles de ML. Préparons-nous à relever de nouveaux défis et à explorer de nouvelles possibilités. Alors, <b>let's go!</b>
# </div>

# %% [markdown]
# <div style="font-size: 1.2em; background-color: #b5add6; padding: 1em; font-weight: bold; color: ;">
# Docker
# <br>
# </div>

# %% [markdown]
# <img style="width: 50%;" src="data:image/png;base64,..."/>

# %% [markdown]
# * Dans la vision Docker, un conteneur ne doit faire tourner qu'un seul processus
# * Docker répond à une problématique forte dans le monde du développement.
# * On retrouve aussi Docker dans les domaines de la CI (Continous Integration, ou Intégration Continue) et de la CD (Continous Delivery, ou Livraison Continue). Cela permet à la CI/CD de créer rapidement des espaces isolés pour faire tourner vos tests.

# %% [markdown]
# <div style="font-size: 1.2em; padding: 1em; font-weight: bold; color: ;">
# <h2>Installation</h2>
# <br>
# </div>
# <br><br>
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# <div style="font-size: 1.2em; padding: 1em; font-weight: bold; color: ;">
# <h2>Premier conteneur en local</h2>
# </div>
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# <div style="font-size: 1.2em; padding: 1em; font-weight: bold; color: ;">
# <h2>Quelques commandes</h2>
# </div>
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# <div style="font-size: 1.2em; padding: 1em; font-weight: bold; color: ;">
# <h2>Fichier Dockerfile</h2>
# </div>
# <img src="data:image/png;base64,..."/>
# <p>.dockerignore</p>

# %% [markdown]
# ```sheel
# docker build -t DAH .
# ```

# %% [markdown]
# <div style="font-size: 1.2em; padding: 1em; font-weight: bold; color: ;">
# <h2>Docker Compose</h2>
# </div>
# Si vous avez utilisé Docker for Mac ou Docker for Windows, vous avez déjà la dernière version de Docker Compose installée dans votre système.
#
# Sur un poste Linux, cela ne sera pas le cas. Vous devez donc le télécharger puis l'installer avec cette ligne de commande (un peu longue, oui !) :

# %% [markdown]
# sudo curl -L "https://github.com/docker/compose/releases/download/1.23.2/docker-compose-$(uname -s)-$(uname -m)" -o /usr/bin/docker-compose && sudo chmod +x /usr/bin/docker-compose

# %% [markdown]
# > docker-compose --version
# docker-compose version 1.23.2, build 1110ad01

# %% [markdown]
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# <div style="font-size: 1.2em; padding: 1em; font-weight: bold; color: ;">
# <h2>Docker Compose file</h2>
# </div>
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# <div style="font-size: 1.2em; background-color: #b5add6; padding: 1em; font-weight: bold; color: ;">
# CI-CD With Github Actions
# <br>
# </div>

# %% [markdown]
# La CI/CD (Continuous Integration/Continuous Deployment) est l’un des principes clés de l’approche DevOps. Elle permet d’accélérer, fiabiliser et sécuriser les applications et les déploiements. DevOps est une approche de collaboration et de culture d’entreprise qui vise à améliorer la communication et la collaboration entre les équipes de développement et d’exploitation.

# %% [markdown]
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# source: <a href="https://www.jems-group.com/fr/le-blog-de-jems/les-solutions-ci-cd-et-lapproche-devops/">https://www.jems-group.com/fr/le-blog-de-jems/les-solutions-ci-cd-et-lapproche-devops/</a>

# %% [markdown]
# Jenkins - GitLab CI - Azure DevOps - **GitHub Actions** - Harness

# %% [markdown]
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# <div style="font-size: 1.2em; padding: 1em; font-weight: bold; color: ;">
# <h2>Github Action</h2>
# </div>
#
# * GitHub Actions est une plateforme d’intégration continue et livraison continue (CI/CD) qui vous permet d’automatiser votre pipeline de génération, de test et de déploiement. Vous pouvez créer des workflows qui créent et testent chaque demande de tirage (pull request) adressée à votre dépôt, ou déployer des demandes de tirage fusionnées en production.
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# <div style="font-size: 1.2em; padding: 1em; font-weight: bold; color: ;">
# <h2>Github Action - Workflows</h2>
# </div>
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# <div style="font-size: 1.2em; padding: 1em; font-weight: bold; color: ;">
# <h2>Github Action - Event</h2>
# </div>
#
# * **Event**: Un événement est une activité spécifique dans un dépôt qui déclenche l'exécution d'un workflow. Par exemple, une activité peut provenir de GitHub quand quelqu’un crée une demande de tirage (pull request), ouvre un problème ou pousse (push) un commit vers un référentiel.<br><br>
# * **Job**: Un travail est un ensemble d'étapes dans un workflow qui s'exécute sur le même exécuteur.<br><br>
# * **Action**: Une action est une application personnalisée pour la plateforme GitHub Actions qui effectue une tâche complexe mais fréquemment répétée.<br><br>
# * **Executer**: Un exécuteur est un serveur qui exécute vos workflows quand ils sont déclenchés. Chaque exécuteur peut exécuter un seul travail à la fois. GitHub fournit les exécuteurs Ubuntu Linux, Microsoft Windows et macOS pour exécuter vos workflows.

# %% [markdown]
# <div style="font-size: 1.2em; padding: 1em; font-weight: bold; color: ;">
# <h2>Github Action - Example</h2>
# </div>
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# <img style="width: 100%;" src="data:image/gif;base64,..."/>

# %% [markdown]
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# Done with love by: Généreux Akotenou - Foo Data Hub Africa Summer School
